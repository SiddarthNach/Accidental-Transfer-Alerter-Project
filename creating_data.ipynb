# %%
import pandas as pd

# %%
bank_data = pd.read_csv("/Users/siddarthnachannagari/Accidental-Transfer-Alerter-Project/Synthetic Bank Transaction Data.csv")

# %%
bank_data.head(20)
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0      1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1      1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2      1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3      1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4      1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# 5      1   PAYMENT    7817.71    C90045638       53860.00        46042.29
# 6      1   PAYMENT    7107.77   C154988899      183195.00       176087.23
# 7      1   PAYMENT    7861.64  C1912850431      176087.23       168225.59
# 8      1   PAYMENT    4024.36  C1265012928        2671.00            0.00
# 9      1     DEBIT    5337.77   C712410124       41720.00        36382.23
# 10     1     DEBIT    9644.94  C1900366749        4465.00            0.00
# 11     1   PAYMENT    3099.97   C249177573       20771.00        17671.03
# ...

# %%
bank_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
bank_data.describe()
#this is not that important (YET)
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
bank_data.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nd/vz39pkrs2r9bwv9tg2ysjr_40000gn/T/ipykernel_12855/1671447443.py in ?()
# ----> 1 bank_data.unique()
#
# /Library/Python/3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
#ok so we dont need the isFraud or Fraud columns so lets drop that from our dataframe

# %%
bank_data.drop(['isFraud', 'isFlaggedFraud'], axis=1, inplace=True)
#so basically when we say axis = 1, we are droping by column not row, and inplace means edit the current dataframe, not to create another one... althought might be useful for other cases

# %%
bank_data.head(10)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest
# 0  M1979787155             0.0            0.00
# 1  M2044282225             0.0            0.00
# ...

# %%
#ok now that we have this, i want to have typical data points that would be useful 
#so lets go do some research on things that would be good to know based on reports of how duplicate or accidental payments happen

# %%
bank_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 436.9+ MB

# %%
pip install faker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 1.9 MB 3.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
import numpy as np
import random

# %%
faker = Faker()
random.seed(42)
np.random.seed(42)

# %%
from datetime import timedelta, datetime

# %%
#lets simulate data from the beginning of this year
start_date = datetime(2025, 1, 1)

# %%
bank_data['timestamp'] = bank_data['step'].apply(lambda x: start_date + timedelta(minutes=int(x * 10)))

# %%
bank_data.head(10)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest           timestamp
# 0  M1979787155             0.0            0.00 2025-01-01 00:10:00
# ...

# %%
bank_data['timestamp'].unique
# Out:
# <bound method Series.unique of 0         2025-01-01 00:10:00
# 1         2025-01-01 00:10:00
# 2         2025-01-01 00:10:00
# 3         2025-01-01 00:10:00
# 4         2025-01-01 00:10:00
#                   ...
# 6362615   2025-01-06 03:50:00
# 6362616   2025-01-06 03:50:00
# 6362617   2025-01-06 03:50:00
# 6362618   2025-01-06 03:50:00
# 6362619   2025-01-06 03:50:00
# Name: timestamp, Length: 6362620, dtype: datetime64[ns]>

# %%
#now lets assign a city location to each of these transactions
cities = ['New York', 'Chicago', 'Los Angeles', 'Houston', 'Phoenix', 'Seattle', 'Boston']
user_city_map = {}

bank_data['location'] = bank_data['nameOrig'].apply(lambda user: user_city_map.setdefault(user, random.choice(cities)))

# %%
#generate a random account number and phone
bank_data['receiverAccount'] = ['ACCT' + ''.join(random.choices('0123456789', k=8)) for _ in range(len(bank_data))]
bank_data['receiverPhone'] = ['+1' + ''.join(random.choices('0123456789', k=10)) for _ in range(len(bank_data))]

# %%
bank_data.head(10)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest           timestamp  \
# 0  M1979787155             0.0            0.00 2025-01-01 00:10:00
# ...

# %%
bank_data.head(10)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest           timestamp  \
# 0  M1979787155             0.0            0.00 2025-01-01 00:10:00
# ...

# %%
bank_data['isAccident'] = 0

# %%
#calculating if the amount transfered is over user mean
user_mean = bank_data.groupby('nameOrig')['amount'].transform('mean')
bank_data.loc[bank_data['amount'] > 5 * user_mean, 'isAccident'] = 1

# %%
#checker bank server status
bank_data['serverStatus'] = 1  

downtime_indices = np.random.choice(bank_data.index, size=int(len(bank_data) * 0.05), replace=False)
bank_data.loc[downtime_indices, 'serverStatus'] = 0

# %%
bank_data.loc[bank_data['serverStatus'] == 0, 'isAccident'] = 1

# %%
location_anomaly_indices = np.random.choice(bank_data.index, size=int(len(bank_data) * 0.03), replace=False)
bank_data.loc[location_anomaly_indices, 'location'] = bank_data.loc[location_anomaly_indices, 'location'].apply(
    lambda loc: random.choice([c for c in cities if c != loc])
)
bank_data.loc[location_anomaly_indices, 'isAccident'] = 1

# %%
#assigning the users a consistent phone address
user_phone_map = {user: '+1' + ''.join(random.choices('0123456789', k=10)) for user in bank_data['nameOrig'].unique()}
bank_data['expectedPhone'] = bank_data['nameOrig'].map(user_phone_map)

# %%
#randomly changing a few phone numbers to simulate accidental transfers
phone_anomaly_indices = np.random.choice(bank_data.index, size=int(len(bank_data) * 0.03), replace=False)
bank_data.loc[phone_anomaly_indices, 'receiverPhone'] = ['+1' + ''.join(random.choices('0123456789', k=10)) for _ in range(len(phone_anomaly_indices))]

# %%
#labelling for mismatch in usual phone numbers and the receiver phone number
bank_data.loc[bank_data['receiverPhone'] != bank_data['expectedPhone'], 'isAccident'] = 1

# %%
bank_data.head(10)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest           timestamp  \
# 0  M1979787155             0.0            0.00 2025-01-01 00:10:00
# ...

# %%
df_accidents = bank_data[bank_data['isAccident'] == 1]

# %%
len(df_accidents)
# Out:
# 6362620

# %%
len(bank_data)
# Out:
# 6362620

# %%
bank_data['isAccident'].value_counts()
# Out:
# isAccident
# 1    6362620
# Name: count, dtype: int64

# %%
bank_data['serverStatus'].value_counts()
# Out:
# serverStatus
# 1    6044489
# 0     318131
# Name: count, dtype: int64

# %%
print("Server down:", (bank_data['serverStatus'] == 0).sum())
print("Big amount anomalies:", (bank_data['amount'] > 5 * user_mean).sum())
print("Location anomalies:", len(location_anomaly_indices))
print("Phone anomalies:", (bank_data['receiverPhone'] != bank_data['expectedPhone']).sum())
print("Final isAccident count:", bank_data['isAccident'].sum())
# Out:
# Server down: 318131
# Big amount anomalies: 0
# Location anomalies: 190878
# Phone anomalies: 6362620
# Final isAccident count: 6362620

# %%
import re

# Normalize phone number to consistent format
def normalize_phone(phone):
    digits = re.sub(r'\D', '', phone)
    return '+1' + digits[-10:]  # last 10 digits

# Assign consistent phone per user
user_phone_map = {}
receiver_phones = []

for user in bank_data['nameOrig']:
    if user not in user_phone_map:
        user_phone_map[user] = '+1' + ''.join(random.choices('0123456789', k=10))
    receiver_phones.append(user_phone_map[user])

bank_data['receiverPhone'] = receiver_phones

# Inject anomalies into 3%
phone_anomaly_indices = np.random.choice(bank_data.index, size=int(len(bank_data) * 0.03), replace=False)
bank_data.loc[phone_anomaly_indices, 'receiverPhone'] = ['+1' + ''.join(random.choices('0123456789', k=10)) for _ in range(len(phone_anomaly_indices))]

# Map expected phones
bank_data['expectedPhone'] = bank_data['nameOrig'].map(user_phone_map)

# Normalize both columns
bank_data['receiverPhone'] = bank_data['receiverPhone'].apply(normalize_phone)
bank_data['expectedPhone'] = bank_data['expectedPhone'].apply(normalize_phone)

# Flag accidents where phones differ
bank_data['isAccident'] |= bank_data['receiverPhone'] != bank_data['expectedPhone']

# Cleanup
bank_data.drop(columns='expectedPhone', inplace=True)

# %%
anomalies_df = bank_data[bank_data['isAccident'] == 1]

# %%
print(anomalies_df.head())
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest           timestamp  \
# 0  M1979787155             0.0             0.0 2025-01-01 00:10:00
# 1  M2044282225             0.0             0.0 2025-01-01 00:10:00
# 2   C553264065             0.0             0.0 2025-01-01 00:10:00
# 3    C38997010         21182.0             0.0 2025-01-01 00:10:00
# 4  M1230701703             0.0             0.0 2025-01-01 00:10:00
#
#       location receiverAccount receiverPhone  isAccident  serverStatus
# ...

# %%
print(f"Total anomalies found: {len(anomalies_df)}")
# Out:
# Total anomalies found: 6362620

# %%
print("Server down anomalies:", ((bank_data['serverStatus'] == 0) & (bank_data['isAccident'] == 1)).sum())
print("High amount anomalies:", ((bank_data['amount'] > 2 * bank_data.groupby('nameOrig')['amount'].transform('mean')) & (bank_data['isAccident'] == 1)).sum())
print("Phone mismatches:", ((bank_data['receiverPhone'] != bank_data['nameOrig'].map(user_phone_map)) & (bank_data['isAccident'] == 1)).sum())
print("Location anomalies:", (bank_data.index.isin(location_anomaly_indices) & (bank_data['isAccident'] == 1)).sum())
# Out:
# Server down anomalies: 318131
# High amount anomalies: 9
# Phone mismatches: 190878
# Location anomalies: 190878

# %%
print("Total rows:", len(bank_data))
# Out:
# Total rows: 6362620

# %%
bank_data['isAccident'] = False

# %%
bank_data['isAccident'] |= (bank_data['serverStatus'] == 0)
bank_data['isAccident'] |= (bank_data['amount'] > 2 * bank_data.groupby('nameOrig')['amount'].transform('mean'))
bank_data['isAccident'] |= (bank_data['receiverPhone'] != bank_data['nameOrig'].map(user_phone_map))
bank_data['isAccident'] |= bank_data.index.isin(location_anomaly_indices)

# %%
print("Total anomalies:", bank_data['isAccident'].sum())
# Out:
# Total anomalies: 675360

# %%
total_anomalies = bank_data['isAccident'].sum()

# %%
average_anomalies = total_anomalies / len(bank_data) * 100

# %%
print(f"Average anomalies per transaction: {average_anomalies:.2f}%")
# Out:
# Average anomalies per transaction: 10.61%

# %%
bank_data.to_csv("synthetic_transactions_labeled.csv", index=False)
